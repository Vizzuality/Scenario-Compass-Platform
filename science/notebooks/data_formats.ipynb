# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd  # noqa: F401
import numpy as np
import json
from pprint import pprint
import sys
import os
from pyam import IamDataFrame, Statistics, filter_by_meta  # noqa: F401

sys.path.append('..')
from src.iasa.iiasa_client import IIASABaseAPIClient
from src.iasa.utils import create_df_from_api_response
# Out:
# [WARNING] 12:21:38 - pint.util: Redefining 'kt' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# [WARNING] 12:21:38 - pint.util: Redefining 'EUR_2005' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# [WARNING] 12:21:38 - pint.util: Redefining 'EUR' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)

# %%
client = IIASABaseAPIClient()

# %% [markdown]
# ### 1. Runs Endpoint

# %%
runs_df = create_df_from_api_response(client.get_data(
    "runs/",
    params={
        "join_parameters": "true",
        "join_runs": "true",
        "table": "true",
    }, ))
runs_df
# Out:
#       model__id  scenario__id  version  is_default    id  \
# 0             1             1        1        True     1
# 1             1             2        1        True     2
# 2             1             3        1        True     3
# 3             1             4        1        True     4
# 4             1             5        1        True     5
# ...         ...           ...      ...         ...   ...
# 1136         41           407        1        True  1158
# 1137         41           408        1        True  1159
# 1138         41           409        1        True  1160
# 1139         41           410        1        True  1161
# 1140         41           411        1        True  1162
#
#                      updated_at updated_by                 created_at  \
# 0    2025-03-28 12:04:39.091252   @unknown 2025-03-28 12:04:24.885658
# 1    2025-03-28 12:04:45.359392   @unknown 2025-03-28 12:04:39.918461
# ...

# %% [markdown]
# ### 2. Regions Endpoint

# %%
runs_df = create_df_from_api_response(client.get_data(
    "regions/",
    params={"table": "true"}
))
runs_df
# Out:
#                                                   name  \
# 0                                                World
# 1                                        International
# 2                                       OECD & EU (R5)
# 3                             Reforming Economies (R5)
# 4                                            Asia (R5)
# ..                                                 ...
# 597  REMIND-MAgPIE 3.5-4.11|Russia and Reforming Ec...
# 598          REMIND-MAgPIE 3.5-4.11|Sub-Saharan Africa
# 599    REMIND-MAgPIE 3.5-4.11|United States of America
# 600                       REMIND-MAgPIE 3.5-4.11|EU 28
# 601             REMIND-MAgPIE 3.5-4.11|Non-EU28 Europe
#
#                   hierarchy   id                 created_at created_by
# 0                    common  318 2025-03-20 15:11:06.387377   @unknown
# 1                    common  320 2025-03-28 11:50:38.561727   @unknown
# 2                        R5  321 2025-03-28 11:50:38.810880   @unknown
# ...

# %% [markdown]
# ### 3. Variables Endpoint

# %%
variables = create_df_from_api_response(client.get_data(
    "iamc/variables/",
    params={"table": "true"}
))
variables
# Out:
#                                                    name    id  \
# 0                                   Agricultural Demand     1
# 1            Agricultural Production|Crops|Energy Crops     2
# 2                Capacity Additions|Electricity|Biomass     3
# 3                   Capacity Additions|Electricity|Coal     4
# 4                    Capacity Additions|Electricity|Gas     5
# ...                                                 ...   ...
# 1979  Final Energy|Industry|Chemicals|Ammonia|Electr...  2020
# 1980  Final Energy|Industry|Chemicals|Ammonia|Gases|...  2021
# 1981  Final Energy|Industry|Chemicals|Ammonia|Liquid...  2022
# 1982      Final Energy|Industry|Chemicals|Ammonia|Other  2023
# 1983  Final Energy|Transportation|Passenger|Gases|Fo...  2024
#
#                       created_at created_by
# 0     2025-03-28T12:04:25.352595   @unknown
# 1     2025-03-28T12:04:25.396617   @unknown
# 2     2025-03-28T12:04:25.436362   @unknown
# ...

# %% [markdown]
# ### 4. Models Endpoint

# %%
models = create_df_from_api_response(
    client.get_data(
        "models/",
        params={
            "join_parameters": "true",
            "join_runs": "true",
            "table": "true",
        },
    )
)

models
# Out:
#                                 name  id                 created_at created_by
# 0                       AIM/CGE V2.2   1 2025-03-28 12:04:24.863850   @unknown
# 1              MESSAGEix-GLOBIOM 1.1   2 2025-03-28 12:40:19.727393   @unknown
# 2                          IMAGE 3.0   3 2025-03-28 12:59:05.024707   @unknown
# 3                          WITCH 5.0   4 2025-03-28 13:22:19.746918   @unknown
# 4                         COFFEE 1.1   5 2025-03-28 13:34:43.084588   @unknown
# 5                       GEM-E3 V2021   6 2025-03-28 14:11:53.838058   @unknown
# 6                   POLES-JRC ENGAGE   7 2025-03-28 16:44:53.587610   @unknown
# 7              REMIND-MAgPIE 2.1-4.2   8 2025-04-02 08:18:31.620923   @unknown
# 8                       TIAM-ECN 1.1   9 2025-04-02 10:21:00.357146   @unknown
# 9                         REMIND 3.0  10 2025-04-07 07:41:37.045853   @unknown
# 10                     PROMETHEUS V1  11 2025-04-07 07:57:18.419906   @unknown
# ...

# %% [markdown]
# ### 5. Scenarios Endpoint

# %%
scenarios = create_df_from_api_response(client.get_data(
    "scenarios/",
    params={"table": "true"}
))
scenarios
# Out:
#                                  name   id                 created_at  \
# 0              ENGAGE-INDCi2030-1000f    1 2025-03-28 12:04:24.883425
# 1               ENGAGE-INDCi2030-1200    2 2025-03-28 12:04:39.918461
# 2              ENGAGE-INDCi2030-1200f    3 2025-03-28 12:04:46.039148
# 3               ENGAGE-INDCi2030-1400    4 2025-03-28 12:04:52.911709
# 4              ENGAGE-INDCi2030-1400f    5 2025-03-28 12:04:59.544864
# ..                                ...  ...                        ...
# 406  COVID-Shift-SelfReliance_max_GDP  407 2025-08-05 19:55:58.805093
# 407  COVID-Shift-SelfReliance_min_GDP  408 2025-08-05 19:56:06.321821
# 408              COVID-Shift-SmartUse  409 2025-08-05 19:56:14.483553
# 409         COVID-Shift-SmartUse_1000  410 2025-08-05 19:56:22.414333
# 410          COVID-Shift-SmartUse_550  411 2025-08-05 19:56:30.638476
#
#     created_by
# 0     @unknown
# 1     @unknown
# 2     @unknown
# 3     @unknown
# 4     @unknown
# ..         ...
# ...

# %% [markdown]
# ### 6. Meta Endpoint

# %%
meta = create_df_from_api_response(client.get_data(
    "meta/",
    params={"table": "True", "join_parameters": "true", "join_runs": "true", "limit": 100000}
))
meta
# Out:
#        run__id                                          key      id  \
# 0            1                                      Project       1
# 1            1             Scientific Manuscript (Citation)       2
# 2            1                  Scientific Manuscript (DOI)       3
# 3            1                            Data Source (DOI)       4
# 4            2                                      Project       5
# ...        ...                                          ...     ...
# 70054     1204           Climate Assessment|Category [Name]  116035
# 70055     1204  Climate Assessment|Processing|Harmonization  116036
# 70056     1204      Climate Assessment|Processing|Infilling  116037
# 70057     1204         Climate Assessment|Processing|Runner  116038
# 70058     1204        Climate Assessment|Processing|Package  116039
#
#                                        value type
# 0                               H2020 ENGAGE  STR
# ...

# %%
# explore meta indicators
metaindicators = create_df_from_api_response(
    client.get_data(
        "meta/",
        params={"join_run_index": "true", "table": "true"},
        body={"run": {"default_only": False}},
    )
)

metaindicators
# Out:
#               model                scenario  version  \
# 0      AIM/CGE V2.2  ENGAGE-INDCi2030-1000f        1
# 1      AIM/CGE V2.2  ENGAGE-INDCi2030-1000f        1
# 2      AIM/CGE V2.2  ENGAGE-INDCi2030-1000f        1
# 3      AIM/CGE V2.2  ENGAGE-INDCi2030-1000f        1
# 4      AIM/CGE V2.2   ENGAGE-INDCi2030-1200        1
# ...             ...                     ...      ...
# 49995     WITCH 5.0         COMMIT-2°C-2030        1
# 49996     WITCH 5.0         COMMIT-2°C-2030        1
# 49997     WITCH 5.0         COMMIT-2°C-2030        1
# 49998     WITCH 5.0         COMMIT-2°C-2030        1
# 49999     WITCH 5.0         COMMIT-2°C-2030        1
#
#                                                      key     id  \
# 0                                                Project      1
# 1                       Scientific Manuscript (Citation)      2
# 2                            Scientific Manuscript (DOI)      3
# 3                                      Data Source (DOI)      4
# ...

# %%
# explore meta indicators
metaindicators = create_df_from_api_response(
    client.get_data(
        "meta/",
        params={"join_run_index": "false", "table": "true"},
        body={"run": {"id__in": [1, 2]}},
    )
)

metaindicators
# Out:
#      run__id                                                key     id  \
# 0          1                                            Project      1
# 1          1                   Scientific Manuscript (Citation)      2
# 2          1                        Scientific Manuscript (DOI)      3
# 3          1                                  Data Source (DOI)      4
# 4          2                                            Project      5
# ..       ...                                                ...    ...
# 127        1  Reason For Concern|Exceeding Prudent Limit For...  96747
# 128        2  Emissions Diagnostics|Cumulative CCS [2020-210...  96748
# 129        2  Reason For Concern|Exceeding Prudent Limit For...  96749
# 130        1  Reason For Concern|Sustainable Bioenergy Use|W...  98664
# 131        2  Reason For Concern|Sustainable Bioenergy Use|W...  98665
#
#                           value   type
# 0                  H2020 ENGAGE    STR
# ...

# %%
data = create_df_from_api_response(
    client.get_data(
        "iamc/datapoints/",
        params={"join_run_index": "false", "join_parameters": "true", "join_runs": "true", "table": "true"},
        body={
            "variable": {"name__in": ["Agricultural Demand"]},
            "region": {"name__in": ["World"]},
        },
    )
)

data
# Out:
#                        model                  scenario  version region  \
# 14              AIM/CGE V2.2    ENGAGE-INDCi2030-1000f        1  World
# 11              AIM/CGE V2.2    ENGAGE-INDCi2030-1000f        1  World
# 9               AIM/CGE V2.2    ENGAGE-INDCi2030-1000f        1  World
# 13              AIM/CGE V2.2    ENGAGE-INDCi2030-1000f        1  World
# 18              AIM/CGE V2.2    ENGAGE-INDCi2030-1000f        1  World
# ...                      ...                       ...      ...    ...
# 10300  MESSAGEix-GLOBIOM 1.0  LowEnergyDemand_1.3_IPCC        1  World
# 10301  MESSAGEix-GLOBIOM 1.0  LowEnergyDemand_1.3_IPCC        1  World
# 10302  MESSAGEix-GLOBIOM 1.0  LowEnergyDemand_1.3_IPCC        1  World
# 10303  MESSAGEix-GLOBIOM 1.0  LowEnergyDemand_1.3_IPCC        1  World
# 10304  MESSAGEix-GLOBIOM 1.0  LowEnergyDemand_1.3_IPCC        1  World
#
#                   unit             variable        value    type  step_year  \
# ...
